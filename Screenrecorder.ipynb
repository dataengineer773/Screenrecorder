# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\dell\miniconda3\lib\site-packages (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pyautogui
# Out:
# Requirement already satisfied: pyautogui in c:\users\dell\miniconda3\lib\site-packages (0.9.54)
# Requirement already satisfied: pymsgbox in c:\users\dell\miniconda3\lib\site-packages (from pyautogui) (2.0.1)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\dell\miniconda3\lib\site-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\dell\miniconda3\lib\site-packages (from pyautogui) (1.0.1)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\dell\miniconda3\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\dell\miniconda3\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in c:\users\dell\miniconda3\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyperclip in c:\users\dell\miniconda3\lib\site-packages (from mouseinfo->pyautogui) (1.11.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\dell\miniconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\dell\miniconda3\lib\site-packages (from opencv-python) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# importing the required packages
import pyautogui
import cv2
import numpy as np

# Specify resolution
resolution = (1920, 1080)

# Specify video codec
codec = cv2.VideoWriter_fourcc(*"XVID")

# Specify name of Output file
filename = "Recording.avi"

# Specify frames rate. We can choose any 
# value and experiment with it
fps = 60.0


# Creating a VideoWriter object
out = cv2.VideoWriter(filename, codec, fps, resolution)

# Create an Empty window
cv2.namedWindow("Live", cv2.WINDOW_NORMAL)

# Resize this window
cv2.resizeWindow("Live", 480, 270)

while True:
    # Take screenshot using PyAutoGUI
    img = pyautogui.screenshot()

    # Convert the screenshot to a numpy array
    frame = np.array(img)

    # Convert it from BGR(Blue, Green, Red) to
    # RGB(Red, Green, Blue)
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Write it to the output file
    out.write(frame)
    
    # Optional: Display the recording screen
    cv2.imshow('Live', frame)
    
    # Stop recording when we press 'q'
    if cv2.waitKey(1) == ord('q'):
        break

# Release the Video writer
out.release()

# Destroy all windows
cv2.destroyAllWindows()
